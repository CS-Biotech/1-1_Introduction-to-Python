# %% [markdown]
# # Week 1: Introduction to Python programming for biology students 🧪
# # Tutorial Module
#
# Welcome! This is the first of many modules in this course designed to help you learn various programming tools for biologists. Over the course of this semester, you will learn the following:
# 1. Python programming
# 2. Data science with Pandas
# 3. Machine Learning fundamentals
#
# The goal of learning programming as a biologist is not to become an expert software developer (although you certainly can!), but to *understand how to use programming as a tool* to:
# 1. Automate and accelerate computation
# 2. Organize and visualize data
# 3. Employ statistical/machine learning models to reach conclusions about datasets
#
# ...all within a scientific context. Whether you will work in a research lab or a corporate setting, these skills will complement your biology background. We hope you find these modules helpful as you continue your undergraduate studies.

# %% [markdown]
# ### Main Module: Python Operations and Logical Flow
#
# New concepts in this module include:
# 1. <span style="background-color: #AFEEEE">**arithmetic operations**</span>
# 2. <span style="background-color: #AFEEEE">**if statements**</span>
# 3. <span style="background-color: #AFEEEE">**lists, the len() function**</span>

# %% [markdown]
# ### Imagine this...
# You are a physician and clinical researcher studying cardiovascular diseases. Your team has recently taken a particular interest in heart failure, one of the leading cardiovascular diseases in Canada. You, along with some of your colleagues, have collected records of patients with stage 3 or 4 heart failure (the final two stages) who were willing to participate in the study. These records include some features of the patient as well as the outcome: whether the patient died or not by the physician's follow-up date. As the lead researcher in this project, your goal is to eventually gain insight into the risk factors that lead to death among heart failure patients.
#
# Over the first 3 modules (weeks 1-3), we will build up skills that will enable you to analyze this heart failure dataset in a Python program using frameworks widely used in industry.

# %% [markdown]
# ### Arithmetic operations
# One of the most basic things you can do in a Python program is arithmetic operations. A summary of some of these operators is shown in the table below.
#
# ![arithmetic.png](data:image/png;base64,...)
#
# Much like in arithmetic expressions that you would write on paper, the order of operations follow PEMDAS (parenthesis, exponent, multiplication/division, addition/subtraction). You must use brackets to explicitly group operations. Notice how the brackets are used in the code snippet below.

# %%
a = 5
x = 1
b = 3

y1 = a*x + b
y2 = a*(x+b)
print("y1 =", y1)
print("y2 =", y2)

# %% [markdown]
# ### Patient chart
#
# Your team is wrapping up the data collection stage this week. Your colleague has asked for your help in adding the last patient, Ahmed, to the dataset. They have given you some of Ahmed's information, stored in the ```patient``` variable, but some values are missing necessary calculations and conversions. Today, you will learn how to manipulate values and perform operations in Python to fix this patient record before you add it to the dataset.

# %% [markdown]
# ---
# **Q1. One of the calculations we are missing for the patient is the ejection fraction (EF), a measure of how well your heart is able to pump blood with each contraction. The formula for EF is as follows:**
#
#
# ![ef.png](data:image/png;base64,...)
#
#
# **You are given the patient's stroke volume (SV) in the variable `v_stroke` and the end-diastolic volume (EDV) in `v_ed`. Complete the following code cell to calculate the patient's ejection fraction, expressed as a percentage value, and store it in `ejection_fraction`.**
#
# <span style="background-color: #FFD700">**Write your code below**</span>

# %%
# ahmed is missing ejection_fraction
# given: stroke volume = 54, end-diastolic volume = 120, EF(%) = s/ed x 100%
v_stroke = 54
v_ed = 120
ejection_fraction = ... # TODO: complete this line
ejection_fraction

# %% [markdown]
# ### Conditional expressions
# Remember when we introduced Boolean variables in the pre-module? Booleans, or the notion of a variable being True or False in general, are very important in programming. This is because to control what happens in our program, we often need to (automatically, using code) check if some condition is what we expect it to be, and then perform some action. Not only can variables be True or False, entire <span style="background-color: #AFEEEE">**expressions**</span> can be True or False!
#
# To construct these expressions, you might combine values, variables, and some <span style="background-color: #AFEEEE">**logical**</span> or <span style="background-color: #AFEEEE">**conditional operators**.</span>
#
# #### **Logical operators**
# In Python, there are 3 logical operators that you should know:
#
# <img src="image-1.png" alt="Drawing" style="width: 600px;"/>
#
# For example, the following is an expression that evaluates to True if var1 is True AND var2 is True. If either var1 or var2 is False, the whole expression evaluates to False. The result of the expression is stored in the variable `result`. Before you run the code, look at the values of var1 and var2- what do you expect `result` to  be?
#
# **Run the code cell below.**

# %%
var1 = True
var2 = False
result = var1 and var2
result

# %% [markdown]
# #### **Comparison operators**
# There are other relationships we can compare. Here is a list of comparison operators, which follow the common mathematical convention:
#
# <img src="image-2.png" alt="Drawing" style="width: 600px;"/>
#
# Below is another example. Again, try to think what the result should be before you run the code, by looking at the values of var1 and var2 and the condition.
#
#  **Run the code cell below.**

# %%
var1 = 10
var2 = 15
result = var1 < var2
result

# %% [markdown]
# ### If statements
# You now know that expressions can evaluate to True or False, sometimes involving logical and comparison operators, but how do we control what actions get performed in certain situations?
#
# **If statements** control the logical flow of your code. Consider the following pseudocode (describing code but in plain English):
# ```
# if condition is true
#     do something
# ```
#
# You can also do something else if the condition is not true:
# ```
# if condition is true
#     do something
# otherwise
#     do something else
# ```
#
# You might have multiple different conditions that are mutually exclusive:
# ```
# if condition A is true
#     do something
# if condition A is not true, but condition B is true
#     do something else
# if condition A and B are not true, but condition C is true
#     do something else
#     ...
# otherwise
#     do something else
# ```
#
# The above situation shows 3 different conditions (A, B, C), but you can have as many conditions as you want. A few rules:
# 1. The first condition should be marked by ```if```.
# 2. All other conditions that follow (if there are any) should be marked by ```elif``` (think of it as "else if")
# 3. An ```else``` statement at the end (if there is one) indicates what should be done if none of the if/elif statements were True. (Think of it as a default)
# 4. You must indent the action(s) under each condition.
#
# The program evaluates each condition from the top until one condition evaluates to True, does the actions in that block, then **jumps** to the end of the if-elif-else block without executing anything else. Thus, the actions under `else` are only executed if NONE of the previous conditions were True. If there is no ```else```, nothing will be done if all conditions evaluate to False.
#
# The full syntax is like this, with as many `elif` blocks as you need:
# ```
# if <condition A>:
#     <do x>
# elif <condition B>:
#     <do y>
# elif <condition C>:
#     <do y>
# else:
#     <do z>
# ```
#
# Say that you want to print something if the patient's age is greater than 40.
#
# **Run the code cell below.**

# %%
# in this example, patient_age is 45. What do you think should happen if you run this code?
patient_age = 45 
if patient_age > 40:
    print("Patient is more than 40 years old!")

# %% [markdown]
# Now change `patient_age` in the above code cell to 30 and run the code again. What happens when you run the code again? Do you see anything in the output?
#
# You will not see anything in the output, because the condition ```patient_age > 40``` was False; therefore, the print statement was skipped. If we want to handle the case where the condition is False, we can add an `else` statement:
#
# **Run the code cell below.**

# %%
patient_age = 30
if patient_age > 40:
    print("Patient is more than 40 years old!")
else:
    print("Patient is 40 years old or younger!")

# %% [markdown]
# Now let's try a slightly more advanced exercise.
#
# Say that you only want to include patients between the ages of 40 (inclusive) and 95 (not inclusive) in your study. You would write an expression like this, and patients that meet the criteria would return True when this expression is evaluated:
# ```
# patient_age >= 40 and patient_age < 95
# ```
#
# Let's break this down. The first part, `patient_age > 40`, is one logical condition. It uses the `>=` comparison operator, so we are evaluating if patient_age is greater than or equal to 40. ```patient_age < 95``` is another logical condition to test if patient_age is less than 95. Lastly, these two conditions are joined by `and`. This means that the condition to the left of `and ` (the first part) must be True **AND** the condition to the right (the second part) must be True for the entire expression to evaluate to True.
#
# You may use brackets to explicitly specify the order that the conditions should be evaluated.
# Run the code below to see an example of how conditional statements work. Do not worry about understanding all parts of the code, but pay attention to the if-else statement.

# %%
patient1 = 35
patient2 = 40
patient3 = 67
patient4 = 100

def handle_patient(patient_age):
    if patient_age >= 40 and patient_age < 95:
        print(f"Patient age: {patient_age}, Include this patient")
    else:
        print(f"Patient age: {patient_age}, Exclude this patient")

handle_patient(patient1)
handle_patient(patient2)
handle_patient(patient3)
handle_patient(patient4)

# %% [markdown]
# **Q2. Complete the code below to assign a binary 0 or 1 to `anaemia` based on its current string value.**
#
# Your colleague has recorded whether the patient has anaemia or not in the variable **`anaemia`**. The value of this variable can be either "Yes" or "No". However, you need to encode this into a binary 0 or 1 so you can work with numbers rather than words later on. The convention is to use **0 for False (No)** and **1 for True (Yes)**.
#
# How would you convert the string to the corresponding binary value? Since you have Ahmed's records right in front of you, you could read them, do the conversion in your head, and assign the correct value to the variable. What if you had to do this conversion for 300 patients? Manual conversion would not be feasible. We want this logic to be **automatic**, so we will use an if statement.
#
# <span style="background-color: #FFD700">**Write your code below**</span>

# %%
# current patient record
patient = ['Ahmed',
 50,
 'No',
 196,
 0,
 None,
 '120/80',
 395000.0,
 1.6,
 136.0,
 1,
 1,
 285.0]

anaemia = patient[2]

# TODO: complete the code block below
if anaemia == ...:
...
...
...

# %% [markdown]
# ### Lists
#
# So far, we have only worked with variables that hold single values, like an integer or a string that says "Hello!". Now is a good time to introduce a new datatype: Lists.
#
# A  <span style="background-color: #AFEEEE">lists</span> can hold multiple values, which are stored linearly. Think of it as a queue of elements, one after the other:
# ![alt text](image-7.png)
#
# In this example, elements include 7, 'cat', 12, 7 again, and so on. The list is the entire green rectangle.
# A few properties of Python lists:
# 1. Elements may be different datatypes, but most commonly we store elements of the same datatype in a list.
# 2. Duplicate values are allowed
# 3. A list may be empty
# 4. A list is zero-indexed (we will explain this later)
#
# To create a list in Python, place the elements of the list inside square brackets, and separate the elements with commas.

# %%
prime = [2, 3, 5, 7, 11]
prime

# %% [markdown]
# We can add elements to the end of a list using **append()**.

# %% [markdown]
# | Function | Input parameters | Output | Syntax |
# | --- | --- | --- | --- |
# | append() | element to be appended | adds the element to the end of the list (however list not printed) | *list*.append(*elmnt*) |

# %%
nucleotides = ['A','T','C']
print("original: ", nucleotides)
nucleotides.append('G')
print("after append: ", nucleotides)

# %% [markdown]
# This code defines a Ahmed's record as a list, which you saw above as well.

# %%
# current patient record
patient = ['Ahmed',
 50,
 'No',
 196,
 0,
 None,
 '120/80',
 395000.0,
 1.6,
 136.0,
 1,
 1,
 285.0]

# %% [markdown]
# **Q3. Let's add some missing information to Ahmed's records. His patient chart says his last check-up was March 12, and he was (obviously) alive at that time. We wish to add the element 0 at the end of the patient list to indicate the patient has survived by the last check-up date.**
#
# <span style="background-color: #FFD700">**Write your code below**</span>

# %%
print("original: ", patient)
... # TODO: use append on this line
print("after append:", patient)

# %% [markdown]
# ### len()
# The <span style="background-color: #AFEEEE">**len()**</span> function in Python gives us the number of elements of a list. We may want to know the length of a list for a number of reasons, but the most important reason is that knowing how many elements there are can protect us from trying to access an element beyond what exists, which would throw an error. We will talk more about accessing elements in the next section.
#
#
# | Function | Input parameters | Output | Syntax |
# | --- | --- | --- | --- |
# | len() | list_name | returns number of characters in that list | len(list_name) |
#
# How many elements are there in **patient**?

# %%
len(patient)

# %% [markdown]
# ### List indexing
# In order to access elements from a list, we need a way to refer to elements by their location. We call this indexing.
#
#  <span style="background-color: #AFEEEE">**Index**</span>: an integer number that refers to a location in a list.
#
# As mentioned earlier, lists are zero-indexed. Zero-indexing means the position of the elements in a list is numbered starting from 0. Because the first element is at position 0, the last element is at position len(list_name) - 1. In this list of 8 elements, the last element is at the 7th index.
#
# <span style="background-color: #AFEEEE">**Zero-indexing**</span>: the position of the elements in a list is numbered starting from 0.
#
# <img src="image-3.png" alt="Drawing" style="width: 400px;"/>
#
#
# If we want to access elements near the end of the list, we can actually index into the list from the back instead of the front. Python allows negative indexing for this purpose. This means the last element is at index -1, the second last element is at index -2, and so on. This is handy if we want to access "the second last element", because we can simply use a negative index of -2 instead of finding out the length of the list using len() and calculating what the second last index would be.
#
# <img src="image-4.png" alt="Drawing" style="width: 400px;"/>
#
# To access a value in a list at index i, we would do list_name[i]. For example,

# %%
patient[0]

# %% [markdown]
# ---
# **Q4. Above, we got the first element (i.e. at index 0) of the list in variable `patient`. How would we get the eighth element from the back of the list?**
#
# <span style="background-color: #FFD700">**Write your code below**</span>

# %%
bp = ... # TODO: get the 8th element from the patient record
bp

# %% [markdown]
# Note that strings can be treated as a list of characters. Therefore, we can use these basic list operations on strings too.

# %%
print(bp[0],bp[1],bp[2])
print(bp[3],bp[4],bp[5])

# %% [markdown]
# ### List slicing
# Now we know how to use list indexing to access a single element. What if we want to get a subset of a list? We can get a subset of a list, from index i (inclusive) to j (NOT inclusive), using list slicing. The syntax is:
#
# list_name[i:j]
#
# Below is a list of daily high temperatures in Celsius for a week in August, starting from Sunday. If we want to know the daily highs for weekdays, we need a subset of this list. If we work out the indices for each day, it would look like this:
#
# <img src="image-5.png" alt="Drawing" style="width: 800px;"/>
#
# Weekdays start at index 1 and end at index 5. Remember that the second index in the slicing operation is NOT inclusive. Therefore, if we try temp[1:5], the operation will not include Friday. The second index needs to be 6:

# %%
# Sunday, Monday, Tuesday, Wednesday, Thursday, Friday, Saturday
temp = [28, 26, 25, 27, 27, 29, 26]
temp[1:6]

# %% [markdown]
# There are some useful shorthands here. If we want a slice of the list from the beginning to some index j (i = 0, the start of the list), we can omit it: list_name[:j]
#
# Conversely, if we want a slice of the list from some index i to the end of the list (j = len(list)-1), we can omit j: list_name[i:]
#
# Say we want to get the first 4 elements of the patient record list. We can do:

# %%
first_4 = patient[:4]
remaining = patient[4:]
first_4

# %% [markdown]
# When we do this, the new lists **first_4** and **remaining** are now separate lists, and each are zero-indexed.
#
# ![alt text](image-6.png)

# %%
# these are the same values
print(patient[6], remaining[2])

# %% [markdown]
# ### List concatenation
# We can concatenate lists (and strings) by using the **+** operator. This will append the lists in the order of your code.

# %%
original = first_4 + remaining
original

# %% [markdown]
# ---
# **Q5. Let's fix Ahmed's high blood pressure record. Currently, it is a string with the systolic value over the diastolic value, with a '/' character to separate the two values. However, we need to record 1 if a patient has high blood pressure and 0 otherwise. A patient has high blood pressure if their systolic blood pressure is over 130 OR if their diastolic blood pressure is over 80.**
#
# Recall that list operations can be done on strings, too. Here is what Ahmed's blood pressure record currently looks like:

# %%
bp

# %% [markdown]
# <span style="background-color: #FFD700">**Write your code below**</span>

# %%
hbp_sys = 130 # systolic high blood pressure
hbp_dia = 80  # diastolic high blood pressure

bp_sys = ...
bp_dia = ...

# TODO: Complete the code block below to assign 0 or 1 to high_blood_pressure based on the current bp 
# measurement
if ... or ...:
...
...
...

# %% [markdown]
# ### Update patient data
# Remember at the beginning of the module, we showed you what the patient record looks like and described it like being a row in a table. Well, now you know that the data was actually a list! Let's print what this variable looks like at the moment:

# %%
patient

# %% [markdown]
# ---
# **Q6. Let's update Ahmed's records with the newly calculated values. Now that you know how to access elements of a list, you also know how to modify them. Recall that we modified ejection fraction, anaemia, and high blood pressure. Here are the instructions:**
# **1. Set the 3rd element (2nd index) of `patient` to the variable `anaemia`, which holds your newly calculated value.
# 2. Set the 6th element of `patient` to the variable `ejection_fraction`, which holds your newly calculated value.
# 3. Set the 7th element of `patient` to the variable `high_blood_pressure`, which holds your newly calculated value.**
#
# <span style="background-color: #FFD700">**Write your code below**</span>

# %%
# TODO: write the code block below

# %% [markdown]
# **Q7. Lastly, we want to remove the patient's name from the records to maintain confidentiality. You can see that the patient's name, Ahmed, is the first element of the list. How would you keep all the elements of the list starting from the 2nd element? It might be useful to review the section on list slicing.**
#
# <span style="background-color: #FFD700">**Write your code below**</span>

# %%
# slice the list starting from 2nd elem (index 1) to remove name
patient = ...

# %% [markdown]
# Great! You should see all the updated values in the list. We're good to go ahead and insert this record back into the patient database. To demonstrate, here's how we add it to the database (you will learn this in week 3!):

# %%
import pandas as pd
df = pd.read_csv("hf_data_raw.csv")
df = df[:302]
df.loc[len(df.index)] = patient
df

# %% [markdown]
# Look at the very last row above; that's Ahmed's record! Great work - you have successfully updated the patient record and learned some Python along the way.
#
# Now let's use the concepts learned above to answer some graded questions.

# %% [markdown]
# ## **Graded Exercise (5 marks)**

# %% [markdown]
# **GQ1. (3 marks) You are assisting one of your colleagues in their research. They are studying DNA sequences for protein synthesis and want to study the part of the sequence relevant to protein translation. They have a very large dataset of DNA sequences, but not all of the sequences are clipped to begin with the start codon for protein translation, **ATG**. They would like your help detecting if a sequence begins with A, T, and G, and automating it through code. Each DNA sequence is represented as a Python list. Your colleague has provided you with an example:**
#
# **`dna_sequence = ['A', 'T', 'G', 'C', 'A', 'T', 'G', 'A', 'C', 'C', 'T', 'A', 'C', 'G']`**
#
# **Your task is to write an if-else statement to check if the first three bases of the given sequence are A, T, and G, which signal the beginning of protein translation. You should print "DNA sequence begins with start codon for protein synthesis" if the first three bases in the list are A, T, and G, respectively. Conversely, print "DNA sequence doesn't begin with start codon for protein synthesis" if the DNA sequence does not meet the requirement.**
#
# <span style="background-color: #FFD700">**Write your code below. The example DNA sequence has been given for you to use in your code. Make sure to check if the result is what you expect!**</span>

# %%
# Do not modify
dna_sequence = ['A', 'T', 'G', 'C', 'A', 'T', 'G', 'A', 'C', 'C', 'T', 'A', 'C', 'G']

# TODO: write your code here
...

# %% [markdown]
# **GQ2. (2 marks) Assuming that the given DNA sequence begins with the start codon for protein synthesis, your colleague would like you to extract the rest of the DNA sequence into a separate list so they can analyse it. Use list slicing to save the DNA sequence *after* the start codon to a new list called `sub_sequence`.**
#
# <span style="background-color: #FFD700">**Write your code in the cell below. The example DNA sequence has been given for you to use in your code.**</span>

# %%
# Do not modify
dna_sequence = ['A', 'T', 'G', 'C', 'A', 'T', 'G', 'A', 'C', 'C', 'T', 'A', 'C', 'G']

# TODO: write your code here
sub_sequence = ...

# Do not modify
sub_sequence

# %% [markdown]
# ## Conclusion
#
# In this module you learned about:
# 1. Arithmetic operators
# 2. Logical/Comparison operators
# 3. If statements
# 4. Lists and list operations (indexing, slicing, concatenating)
# 5. Built-in functions like print(), len()

# %% [markdown]
# ## Further Reading
# <span style="background-color: #AFEEEE">* **Summary of Markdown elements**</span>: https://www.markdownguide.org/cheat-sheet/.
#
#
# <span style="background-color: #AFEEEE">* **Python printing**</span>: There are many more advanced ways to print strings and variables with different formatting. You can read Python documentation for input and output formatting here: https://docs.python.org/3/tutorial/inputoutput.html
